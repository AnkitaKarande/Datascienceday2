# %%
a=True
print ("a")
# Out:
# a

# %%
a=10**2
print a
# Out:
# 100

# %%
import pandas as pd
data=pd.DataFrame({'group':['a','a','a','b','b','b','c','c','c'],'ounces':[4,3,12,6,7.5,8,3,5,6],'sr.no':[1,2,3,4,5,6,7,8,9]})
data
# Out:
#   group  ounces  sr.no
# 0     a     4.0      1
# 1     a     3.0      2
# 2     a    12.0      3
# 3     b     6.0      4
# 4     b     7.5      5
# 5     b     8.0      6
# 6     c     3.0      7
# 7     c     5.0      8
# 8     c     6.0      9

# %%
data.describe()
# Out:
#           ounces
# count   9.000000
# mean    6.055556
# std     2.855307
# min     3.000000
# 25%     4.000000
# 50%     6.000000
# 75%     7.500000
# max    12.000000

# %%
data.info
# Out:
# <bound method DataFrame.info of   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0>

# %%
data.sort_values(by=['group','ounces'],ascending=[False,True],inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-46d1f011a8ec> in <module>()
# ----> 1 data.sort_values(by=['group','ounces'],ascending=[False,True],inplace=True)
#       2 data
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3137             keys = []
#    3138             for x in by:
# -> 3139                 k = self[x].values
#    3140                 if k.ndim == 2:
#    3141                     raise ValueError('Cannot sort by duplicate column %s' %
#
# C:\Program Files\Anaconda2\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# ...

# %%
import pandas as pd
data = pd.DataFrame({'k1':['one'] * 3 + ['two'] * 4, 'k2':[5,3,4,5,5,6,6]})
data
# Out:
#     k1  k2
# 0  one   5
# 1  one   3
# 2  one   4
# 3  two   5
# 4  two   5
# 5  two   6
# 6  two   6

# %%
data.drop_duplicates()
data
# Out:
#     k1  k2
# 0  one   5
# 1  one   3
# 2  one   4
# 3  two   5
# 4  two   5
# 5  two   6
# 6  two   6

# %%
data.drop_duplicates(subset='k1')
data
# Out:
#     k1  k2
# 0  one   5
# 1  one   3
# 2  one   4
# 3  two   5
# 4  two   5
# 5  two   6
# 6  two   6

# %%
data.sort_values(by='k2')
data
# Out:
#     k1  k2
# 0  one   5
# 1  one   3
# 2  one   4
# 3  two   5
# 4  two   5
# 5  two   6
# 6  two   6

# %%
data.drop_duplicates()
data
# Out:
#     k1  k2
# 0  one   5
# 1  one   3
# 2  one   4
# 3  two   5
# 4  two   5
# 5  two   6
# 6  two   6

# %%
import pandas as pd
data= pd.DataFrame({'food':['bacon','pulled pork','bacon','pastram'],'ounces':[4,5,7,8]})
data
# Out:
#           food  ounces
# 0        bacon       4
# 1  pulled pork       5
# 2        bacon       7
# 3      pastram       8

# %%
data['animal2'] = data.apply(meat2animal,axis='columns')
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-ca4b5154edc9> in <module>()
# ----> 1 data['animal2'] = data.apply(meat2animal,axis='columns')
#       2 data
#       3
#
# NameError: name 'meat2animal' is not defined

# %%
import pandas as pd
data=pd.read_exel('C:\Users\Dell\Downloads\ml-1m' sheetname="movies")
# Out:
#   File "<ipython-input-46-070eb752a151>", line 2
#     data=pd.read_exel('C:\Users\Dell\Downloads\ml-1m' sheetname="movies")
#                                                               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
data=pd.read_excel('C:\Users\Dell\Downloads\ml-1m\m.xls', sheetname="movies")
data
# Out:
#        1::Toy Story (1995)::Animation|Children's|Comedy  \
# 0       2::Jumanji (1995)::Adventure|Children's|Fantasy
# 1            3::Grumpier Old Men (1995)::Comedy|Romance
# 2             4::Waiting to Exhale (1995)::Comedy|Drama
# 3         5::Father of the Bride Part II (1995)::Comedy
# 4                 6::Heat (1995)::Action|Crime|Thriller
# 5                     7::Sabrina (1995)::Comedy|Romance
# 6          8::Tom and Huck (1995)::Adventure|Children's
# 7                        9::Sudden Death (1995)::Action
# 8       10::GoldenEye (1995)::Action|Adventure|Thriller
# 9                                11::American President
# 10    12::Dracula: Dead and Loving It (1995)::Comedy...
# 11               13::Balto (1995)::Animation|Children's
# 12                              14::Nixon (1995)::Drama
# 13    15::Cutthroat Island (1995)::Action|Adventure|...
# 14                    16::Casino (1995)::Drama|Thriller
# 15      17::Sense and Sensibility (1995)::Drama|Romance
# ...
